# %%
library(e1071)

# %%
dataset <- read.csv("../input/uas-svm/UAS_SVM.csv", header = TRUE, sep = ";")
head(dataset)
# Out:
#   Customer.ID Age Income Education Occupation Income.1 Average.Balance
# 1 1234561427  4   5      5         3          1        1
# 2 1234561518  3   2      4         5          3        1
# 3 1234561282  3   1      3         2          3        3
# 4 1234561064  3   3      2         1          2        2
# 5 1234561043  2   4      5         4          4        1
# 6 1234561619  5   4      4         1          4        4
#   Appraisal Industri Pelunasan.Kredit
# 1 5         5        1
# 2 2         4        0
# 3 1         2        1
# 4 5         5        0
# 5 1         1        1
# 6 1         2        1

# %%
dim(dataset)
# Out:
# [1] 999  10

# %%
n=round(nrow(dataset)*0.70)

# %%
n
# Out:
# [1] 699

# %%
set.seed(56271)

# %%
sample=sample(seq_len(nrow(dataset)), size = n)

# %%
train=dataset[sample, ]

# %%
dim(train)
# Out:
# [1] 699  10

# %%
test=dataset[-sample, ]

# %%
dim(test)
# Out:
# [1] 300  10

# %%
data.svm<-svm(factor(Pelunasan.Kredit) ~., data = train, probability=T)

# %%
head(data.svm)
# Out:
# $call
# svm(formula = factor(Pelunasan.Kredit) ~ ., data = train, probability = T)
#
# $type
# [1] 0
#
# $kernel
# [1] 2
#
# $cost
# [1] 1
#
# $degree
# [1] 3
#
# $gamma
# [1] 0.1111111

# %%
prediks1 <- predict(data.svm, train, decision.values=T, probability=T)

# %%
head(prediks1)
# Out:
# 998 994 134 706 556 537
#   1   1   1   0   1   1
# Levels: 0 1

# %%
confusionMatrix(factor(train$Pelunasan.Kredit), factor(prediks1))
# Out:
# Confusion Matrix and Statistics
#
#           Reference
# Prediction   0   1
#          0   8 329
#          1  86 276
#
#                Accuracy : 0.4063
#                  95% CI : (0.3696, 0.4438)
#     No Information Rate : 0.8655
#     P-Value [Acc > NIR] : 1
#
#                   Kappa : -0.2193
#
#  Mcnemar's Test P-Value : <2e-16
#
#             Sensitivity : 0.08511
#             Specificity : 0.45620
#          Pos Pred Value : 0.02374
#          Neg Pred Value : 0.76243
#              Prevalence : 0.13448
#          Detection Rate : 0.01144
#    Detection Prevalence : 0.48212
#       Balanced Accuracy : 0.27065
#
#        'Positive' Class : 0

# %%
prediks1 <- predict(data.svm, test, decision.values=T, probability=T)

# %%
head(prediks1)
# Out:
#  3  6  7  8 18 30
#  1  0  0  1  1  1
# Levels: 0 1

# %%
confusionMatrix(factor(test$Pelunasan.Kredit), factor(prediks1))
# Out:
# Confusion Matrix and Statistics
#
#           Reference
# Prediction   0   1
#          0  17 122
#          1  18 143
#
#                Accuracy : 0.5333
#                  95% CI : (0.4751, 0.5909)
#     No Information Rate : 0.8833
#     P-Value [Acc > NIR] : 1
#
#                   Kappa : 0.0111
#
#  Mcnemar's Test P-Value : <2e-16
#
#             Sensitivity : 0.48571
#             Specificity : 0.53962
#          Pos Pred Value : 0.12230
#          Neg Pred Value : 0.88820
#              Prevalence : 0.11667
#          Detection Rate : 0.05667
#    Detection Prevalence : 0.46333
#       Balanced Accuracy : 0.51267
#
#        'Positive' Class : 0
